# %% [markdown]
# # testing the utils

# %%
import googlemaps
import requests
from IPython.display import display
import math
import numpy as np
from scipy.optimize import linprog
from PIL import Image
import io
import cv2
import string
import time
from global_land_mask import globe
from geopy.distance import geodesic, distance
import utils
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-9a0dc5d598ab> in <module>
#      12 from global_land_mask import globe
#      13 from geopy.distance import geodesic, distance
# ---> 14 import utils
#
# /mnt/h/Documents/fifth_year_shit/math441/project/utils.py in <module>
#      14
#      15 api_key = open("googlemaps-apikey.txt", "r").read()
# ---> 16 client = googlemaps.Client(key=api_key)
#      17
#      18 # def get_map(center, markers=[], marker_color="blue", zoom=13, fill=False):
#
# ~/.local/lib/python3.8/site-packages/googlemaps/client.py in __init__(self, key, client_id, client_secret, timeout, connect_timeout, read_timeout, retry_timeout, requests_kwargs, queries_per_second, channel, retry_over_query_limit, experience_id, requests_session, base_url)
#     132
#     133         if key and not key.startswith("AIza"):
# ...

# %%
test_positions_burnaby = [
    (49.237564, -123.044866)
]

display(utils.get_map(test_positions_burnaby[0], markers=[("blue",test_positions_burnaby)], zoom=11))
display(utils.get_map(test_positions_burnaby[0], markers=[("red",test_positions_burnaby)], fills=[utils.distance_coverable(test_positions_burnaby[0])], zoom=11))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-40dbdff4c493> in <module>
#       3 ]
#       4
# ----> 5 display(utils.get_map(test_positions_burnaby[0], markers=[("blue",test_positions_burnaby)], zoom=11))
#       6 display(utils.get_map(test_positions_burnaby[0], markers=[("red",test_positions_burnaby)], fills=[utils.distance_coverable(test_positions_burnaby[0])], zoom=11))
#
# NameError: name 'utils' is not defined

# %%
kits_oceanside = (49.271532, -123.179601)
display(utils.get_map(kits_oceanside, markers=[("blue",[kits_oceanside])], zoom=11))
display(utils.get_map(kits_oceanside, markers=[("red",[kits_oceanside])], fills=[utils.distance_coverable(kits_oceanside)], zoom=11))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=400x400>
# <PIL.PngImagePlugin.PngImageFile image mode=P size=400x400>
